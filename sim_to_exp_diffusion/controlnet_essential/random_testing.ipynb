# %%
import os
import preprocess_seed_graybackground
base_folder_i="/hpc/group/youlab/ks723/storage/MATLAB_SIMS/Sim_031524/Selected_v4_ALL_input_100AUG"


for filename in os.listdir(base_folder_i):
    if filename.endswith(".png") or filename.endswith(".jpg"):
        file=preprocess_seed_graybackground(os.path.join(base_folder_i,filename))
        print(  file.shape)
        break
